# %% [markdown]
# <a href="https://colab.research.google.com/github/EmilyHong77/gentrification_in_montreal/blob/main/ding_measures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Information**<br>
# Ding Measures Source:<br>

# %% [markdown]
# **Mount Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Libraries**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Merge Datasets

# %%
# Read in the data
standardized_2001 = pd.read_csv('/content/drive/MyDrive/Ai4Good_Project/GentrificAItion/montreal_data_processing/data_cleaning/4_standardized_data/2001_standardized.csv')
standardized_2006 = pd.read_csv('/content/drive/MyDrive/Ai4Good_Project/GentrificAItion/montreal_data_processing/data_cleaning/4_standardized_data/2006_standardized.csv')
standardized_2011 = pd.read_csv('/content/drive/MyDrive/Ai4Good_Project/GentrificAItion/montreal_data_processing/data_cleaning/4_standardized_data/2006_standardized.csv')
standardized_2016 = pd.read_csv('/content/drive/MyDrive/Ai4Good_Project/GentrificAItion/montreal_data_processing/data_cleaning/4_standardized_data/2011_standardized.csv')
standardized_2021 = pd.read_csv('/content/drive/MyDrive/Ai4Good_Project/GentrificAItion/montreal_data_processing/data_cleaning/2_clean_data/2021_clean.csv')

# %%
#clean 2001-2016 drop NaNs
standardized_2001 = standardized_2001.dropna()
standardized_2006 = standardized_2006.dropna()
standardized_2011 = standardized_2011.dropna()
standardized_2016 = standardized_2016.dropna()


print(len(standardized_2001.columns))
print(standardized_2001.head())
print(len(standardized_2006.columns))
print(standardized_2006.head())
print(len(standardized_2011.columns))
print(standardized_2011.head())
print(len(standardized_2016.columns))
print(standardized_2016.head())
print(len(standardized_2021.columns))
print(standardized_2021.head())
# Out:
# 69
#      GeoUID_2021  Population_2001  Population 0 to 9_2001  \
# 616    4620001.0           2445.0                   240.0
# 617    4620002.0           2734.0                   275.0
# 618    4620003.0           6522.0                   675.0
# 619    4620004.0           3213.0                   270.0
# 620    4620005.0           3171.0                   265.0
#
#      Population 10 to 19_2001  Population 20 to 29_2001  \
# 616                     225.0                     295.0
# 617                     305.0                     325.0
# 618                     765.0                     840.0
# 619                     335.0                     385.0
# 620                     305.0                     370.0
#
#      Population 30 to 39_2001  Population 40 to 49_2001  \
# 616                     360.0                     455.0
# 617                     405.0                     465.0
# 618                     950.0                    1150.0
# 619                     435.0                     590.0
# 620                     430.0                     575.0
#
#      Population 50 to 59_2001  Population 60 plus_2001  \
# 616                     365.0                    510.0
# 617                     320.0                    635.0
# 618                     905.0                   1245.0
# 619                     445.0                    760.0
# 620                     495.0                    735.0
#
#      Total male population_2001  ...  Regular maintenance_2001  \
# 616                      1185.0  ...                    1055.0
# 617                      1280.0  ...                    1180.0
# 618                      3055.0  ...                    2645.0
# 619                      1505.0  ...                    1425.0
# 620                      1520.0  ...                    1440.0
#
#      Owned housing_2001  Rented housing_2001  Band housing_2001  Owner_2001  \
# 616               440.0                725.0                0.0       440.0
# 617               435.0                840.0                0.0       435.0
# 618              1105.0               1745.0                0.0      1105.0
# 619               530.0                990.0                0.0       535.0
# 620               460.0               1105.0                0.0       465.0
#
#      Tenant_2001  Median household income ($)_2001  \
# 616        725.0                           35290.0
# 617        840.0                           29350.0
# 618       1725.0                           37964.0
# 619        990.0                           36555.0
# 620       1105.0                           31308.0
#
#      Average gross rent ($)_2001  Average value dwelling ($)_2001  \
# 616                        554.0                         107148.0
# 617                        528.0                         107098.0
# 618                        541.0                         139439.0
# 619                        533.0                         129464.0
# 620                        504.0                         120973.0
#
#      Population change (%)_2001
# 616                         2.4
# 617                        -2.8
# 618                        -0.1
# 619                         2.7
# 620                        -1.4
#
# [5 rows x 69 columns]
# 69
#      GeoUID_2021  Population_2006  Population 0 to 9_2006  \
# 650    4620001.0           2498.0                   205.0
# 651    4620002.0           2819.0                   250.0
# 652    4620003.0           6407.0                   585.0
# 653    4620004.0           3223.0                   225.0
# 654    4620005.0           3188.0                   245.0
#
#      Population 10 to 19_2006  Population 20 to 29_2006  \
# 650                     240.0                     325.0
# 651                     340.0                     375.0
# 652                     715.0                     860.0
# 653                     335.0                     430.0
# 654                     310.0                     400.0
#
#      Population 30 to 39_2006  Population 40 to 49_2006  \
# 650                     345.0                     480.0
# 651                     395.0                     460.0
# 652                     785.0                    1090.0
# 653                     375.0                     555.0
# 654                     430.0                     580.0
#
#      Population 50 to 59_2006  Population 60 plus_2006  \
# 650                     380.0                    520.0
# 651                     375.0                    620.0
# 652                    1010.0                   1375.0
# 653                     510.0                    785.0
# 654                     515.0                    725.0
#
#      Total male population_2006  ...  Regular maintenance_2006  \
# 650                      1215.0  ...                    1125.0
# 651                      1345.0  ...                    1240.0
# 652                      3030.0  ...                    2665.0
# 653                      1515.0  ...                    1455.0
# 654                      1535.0  ...                    1455.0
#
#      Owned housing_2006  Rented housing_2006  Band housing_2006  Owner_2006  \
# 650               520.0                720.0                0.0       525.0
# 651               555.0                785.0                0.0       555.0
# 652              1230.0               1655.0                0.0      1230.0
# 653               620.0                940.0                0.0       615.0
# 654               535.0               1060.0                0.0       535.0
#
#      Tenant_2006  Median household income ($)_2006  \
# 650        720.0                           42059.0
# 651        785.0                           40115.0
# 652       1655.0                           43553.0
# 653        940.0                           38945.0
# 654       1060.0                           41290.0
#
#      Average gross rent ($)_2006  Average value dwelling ($)_2006  \
# 650                        599.0                         199403.0
# 651                        592.0                         205372.0
# 652                        591.0                         243052.0
# 653                        563.0                         204537.0
# 654                        569.0                         210709.0
#
#      Population change (%)_2006
# 650                         2.2
# 651                         3.1
# 652                        -1.8
# 653                         0.3
# 654                         0.5
#
# [5 rows x 69 columns]
# 69
#      GeoUID_2021  Population_2006  Population 0 to 9_2006  \
# 650    4620001.0           2498.0                   205.0
# 651    4620002.0           2819.0                   250.0
# 652    4620003.0           6407.0                   585.0
# 653    4620004.0           3223.0                   225.0
# 654    4620005.0           3188.0                   245.0
#
#      Population 10 to 19_2006  Population 20 to 29_2006  \
# 650                     240.0                     325.0
# 651                     340.0                     375.0
# 652                     715.0                     860.0
# 653                     335.0                     430.0
# 654                     310.0                     400.0
#
#      Population 30 to 39_2006  Population 40 to 49_2006  \
# 650                     345.0                     480.0
# 651                     395.0                     460.0
# 652                     785.0                    1090.0
# 653                     375.0                     555.0
# 654                     430.0                     580.0
#
#      Population 50 to 59_2006  Population 60 plus_2006  \
# 650                     380.0                    520.0
# 651                     375.0                    620.0
# 652                    1010.0                   1375.0
# 653                     510.0                    785.0
# 654                     515.0                    725.0
#
#      Total male population_2006  ...  Regular maintenance_2006  \
# 650                      1215.0  ...                    1125.0
# 651                      1345.0  ...                    1240.0
# 652                      3030.0  ...                    2665.0
# 653                      1515.0  ...                    1455.0
# 654                      1535.0  ...                    1455.0
#
#      Owned housing_2006  Rented housing_2006  Band housing_2006  Owner_2006  \
# 650               520.0                720.0                0.0       525.0
# 651               555.0                785.0                0.0       555.0
# 652              1230.0               1655.0                0.0      1230.0
# 653               620.0                940.0                0.0       615.0
# 654               535.0               1060.0                0.0       535.0
#
#      Tenant_2006  Median household income ($)_2006  \
# 650        720.0                           42059.0
# 651        785.0                           40115.0
# 652       1655.0                           43553.0
# 653        940.0                           38945.0
# 654       1060.0                           41290.0
#
#      Average gross rent ($)_2006  Average value dwelling ($)_2006  \
# 650                        599.0                         199403.0
# 651                        592.0                         205372.0
# 652                        591.0                         243052.0
# 653                        563.0                         204537.0
# 654                        569.0                         210709.0
#
#      Population change (%)_2006
# 650                         2.2
# 651                         3.1
# 652                        -1.8
# 653                         0.3
# 654                         0.5
#
# [5 rows x 69 columns]
# 68
#      GeoUID_2021  Population_2011  Population 0 to 9_2011  \
# 654    4620001.0           2608.0                   210.0
# 655    4620002.0           3039.0                   285.0
# 656    4620003.0           6238.0                   610.0
# 657    4620004.0           3261.0                   265.0
# 658    4620005.0           3163.0                   270.0
#
#      Population 10 to 19_2011  Population 20 to 29_2011  \
# 654                     240.0                     350.0
# 655                     315.0                     360.0
# 656                     610.0                     785.0
# 657                     305.0                     420.0
# 658                     270.0                     395.0
#
#      Population 30 to 39_2011  Population 40 to 49_2011  \
# 654                     365.0                     380.0
# 655                     420.0                     455.0
# 656                     805.0                     900.0
# 657                     420.0                     445.0
# 658                     435.0                     465.0
#
#      Population 50 to 59_2011  Population 60 plus_2011  \
# 654                     505.0                    550.0
# 655                     450.0                    760.0
# 656                    1105.0                   1430.0
# 657                     620.0                    785.0
# 658                     555.0                    760.0
#
#      Total male population_2011  ...  Major repairs_2011  \
# 654                      1310.0  ...               125.0
# 655                      1420.0  ...               145.0
# 656                      2955.0  ...               240.0
# 657                      1585.0  ...               100.0
# 658                      1570.0  ...               110.0
#
#      Regular maintenance_2011  Owned housing_2011  Rented housing_2011  \
# 654                    1195.0               615.0                700.0
# 655                    1400.0               525.0               1025.0
# 656                    2635.0              1260.0               1615.0
# 657                    1515.0               615.0               1000.0
# 658                    1520.0               665.0                965.0
#
#      Band housing_2011  Owner_2011  Tenant_2011  \
# 654                0.0       620.0        705.0
# 655                0.0       525.0       1025.0
# 656                0.0      1255.0       1615.0
# 657                0.0       615.0        995.0
# 658                0.0       660.0        965.0
#
#      Median household income ($)_2011  Average gross rent ($)_2011  \
# 654                           47893.0                        658.0
# 655                           39967.0                        674.0
# 656                           46118.0                        673.0
# 657                           39998.0                        610.0
# 658                           44024.0                        665.0
#
#      Average value dwelling ($)_2011
# 654                         285258.0
# 655                         403919.0
# 656                         333478.0
# 657                         300657.0
# 658                         295716.0
#
# [5 rows x 68 columns]
# 70
#    GeoUID_2021  Area (sq km)_2021  Population_2021  Dwellings_2021  \
# 0    4620001.0             0.4643             2684            1463
# 1    4620002.0             0.3858             3780            2022
# 2    4620003.0             0.7401             6600            3174
# 3    4620004.0             0.4470             3355            1744
# 4    4620005.0             0.5652             3175            1774
#
#    Households_2021  Total male population_2021  Total female population_2021  \
# 0             1402                      1350.0                        1335.0
# 1             1944                      1825.0                        1955.0
# 2             3016                      3210.0                        3390.0
# 3             1646                      1690.0                        1660.0
# 4             1636                      1585.0                        1590.0
#
#    Population change (%)_2021  Non-movers_2021  Movers_2021  ...  Owner_2021  \
# 0                         1.7           2205.0        340.0  ...       610.0
# 1                         7.5           3205.0        535.0  ...       755.0
# 2                         3.6           5770.0        735.0  ...      1190.0
# 3                         5.6           2670.0        470.0  ...       630.0
# 4                         3.8           2710.0        455.0  ...       525.0
#
#    Tenant_2021  Population 0 to 9_2021  Population 10 to 19_2021  \
# 0        770.0                   250.0                     200.0
# 1       1195.0                   440.0                     345.0
# 2       1840.0                   775.0                     630.0
# 3       1005.0                   330.0                     280.0
# 4       1125.0                   340.0                     270.0
#
#    Population 20 to 29_2021  Population 30 to 39_2021  \
# 0                     375.0                     440.0
# 1                     470.0                     605.0
# 2                     815.0                     985.0
# 3                     435.0                     510.0
# 4                     370.0                     515.0
#
#    Population 40 to 49_2021  Population 50 to 59_2021  \
# 0                     335.0                     400.0
# 1                     510.0                     525.0
# 2                     885.0                     875.0
# 3                     445.0                     470.0
# 4                     435.0                     425.0
#
#    Population 60 plus_2021  Allophone_2021
# 0                    675.0           180.0
# 1                    890.0           300.0
# 2                   1640.0           725.0
# 3                    885.0           275.0
# 4                    815.0           160.0
#
# [5 rows x 70 columns]

# %%
# merge csvs to a single file
merged_df = pd.merge(standardized_2001, standardized_2006, on='GeoUID_2021', how='outer')
merged_df = pd.merge(merged_df, standardized_2011, on='GeoUID_2021', how='outer')
merged_df = pd.merge(merged_df, standardized_2016, on='GeoUID_2021', how='outer')
merged_df = pd.merge(merged_df, standardized_2021, on='GeoUID_2021', how='outer')
merged_df.head()
# Out:
#    GeoUID_2021  Population_2001  Population 0 to 9_2001  \
# 0    4620001.0           2445.0                   240.0
# 1    4620002.0           2734.0                   275.0
# 2    4620003.0           6522.0                   675.0
# 3    4620004.0           3213.0                   270.0
# 4    4620005.0           3171.0                   265.0
#
#    Population 10 to 19_2001  Population 20 to 29_2001  \
# 0                     225.0                     295.0
# 1                     305.0                     325.0
# 2                     765.0                     840.0
# 3                     335.0                     385.0
# 4                     305.0                     370.0
#
#    Population 30 to 39_2001  Population 40 to 49_2001  \
# 0                     360.0                     455.0
# 1                     405.0                     465.0
# 2                     950.0                    1150.0
# 3                     435.0                     590.0
# 4                     430.0                     575.0
#
#    Population 50 to 59_2001  Population 60 plus_2001  \
# 0                     365.0                    510.0
# 1                     320.0                    635.0
# 2                     905.0                   1245.0
# 3                     445.0                    760.0
# 4                     495.0                    735.0
#
#    Total male population_2001  ...  Owner_2021  Tenant_2021  \
# 0                      1185.0  ...       610.0        770.0
# 1                      1280.0  ...       755.0       1195.0
# 2                      3055.0  ...      1190.0       1840.0
# 3                      1505.0  ...       630.0       1005.0
# 4                      1520.0  ...       525.0       1125.0
#
#    Population 0 to 9_2021  Population 10 to 19_2021  Population 20 to 29_2021  \
# 0                   250.0                     200.0                     375.0
# 1                   440.0                     345.0                     470.0
# 2                   775.0                     630.0                     815.0
# 3                   330.0                     280.0                     435.0
# 4                   340.0                     270.0                     370.0
#
#    Population 30 to 39_2021  Population 40 to 49_2021  \
# 0                     440.0                     335.0
# 1                     605.0                     510.0
# 2                     985.0                     885.0
# 3                     510.0                     445.0
# 4                     515.0                     435.0
#
#    Population 50 to 59_2021  Population 60 plus_2021  Allophone_2021
# 0                     400.0                    675.0           180.0
# 1                     525.0                    890.0           300.0
# 2                     875.0                   1640.0           725.0
# 3                     470.0                    885.0           275.0
# 4                     425.0                    815.0           160.0
#
# [5 rows x 341 columns]

# %%
#export to drive
merged_df.to_csv('/content/drive/MyDrive/Ai4Good_Project/GentrificAItion/montreal_data_processing/data_cleaning/5_ding_measurements/merged_data.csv', index=False)

# %% [markdown]
# # Ding Measurements

# %% [markdown]
# **Ding Measurements**
# 1. Gentrifiable Measure
# 2. Gentrified Measure
# 3. Gentrification Levels

# %% [markdown]
# ## Gentrifiable Measure
#
# **Formula**:<br>
# median household income < median of CMA
# - CMA 2001: 47267 (Census data)
# - CMA 2006: 47979 (Census data)
# - CMA 2011: 53024 (Stats Can)
# - CMA 2016: 61970 (Stats Can)
# - CMA 2021: 462

# %% [markdown]
# ## Gentrified Measure
#
# **Formula**<br>
# increase university degrees > median for CMA <br>
# increase in housing value > median for CMA <br>
# increase in renting costs > median for CMA

# %% [markdown]
# ## Gentrification Levels
#
# **Formula**<br>
# Weak: rent or housing value increased ≤
#  25th percentile<br>
# Moderate: rent or housing value increased with the 25th - 75th percentile<br>
# Intense: rent or housing value increased > 75th percentile
